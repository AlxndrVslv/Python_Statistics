# %% [markdown]
# <a href="https://colab.research.google.com/github/AlxndrVslv/Python_Statistics/blob/master/EDA_gas_Korea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### EDA для квиза по описательной статистике
#
# Использовался датасет с [Kaggle](https://www.kaggle.com/datasets/zxtzxt30/korea-monthly-gas-sales-with-temperature?resource=download)

# %%
import pandas as pd

# %%
df = pd.read_csv('gas_sales_1.csv')
df.head(5)
# Out:
#    Year  Month  Temperature  Gangwondo   Seoul  Gyeonggido  Incheon  \
# 0  2000      1        -1.20      16219  662424      363014   139454
# 1  2000      2        -0.99      16280  689177      375937   145834
# 2  2000      3         6.64      14105  566528      323145   121324
# 3  2000      4        12.11      10364  396231      237437    91421
# 4  2000      5        17.59       6843  262940      169495    67239
#
#    Gyeongsangnamdo  Gyeongsangbukdo  Gwangju  ...  Daejeon  Busan  Sejong  \
# 0            42129            55362    39465  ...    52992  85787       0
# 1            42604            52863    40674  ...    53950  87282       0
# 2            35990            47282    34610  ...    41898  74476       0
# 3            28698            40393    25898  ...    28618  58316       0
# 4            21073            35083    18426  ...    17503  45915       0
#
#    Ulsan  Jeollanamdo  Jeollabukdo  Jeju  Chungcheongnamdo  Chungcheongbukdo  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              252 non-null    int64
#  1   Month             252 non-null    int64
#  2   Temperature       252 non-null    float64
#  3   Gangwondo         252 non-null    int64
#  4   Seoul             252 non-null    int64
#  5   Gyeonggido        252 non-null    int64
#  6   Incheon           252 non-null    int64
#  7   Gyeongsangnamdo   252 non-null    int64
#  8   Gyeongsangbukdo   252 non-null    int64
#  9   Gwangju           252 non-null    int64
#  10  Daegu             252 non-null    int64
#  11  Daejeon           252 non-null    int64
#  12  Busan             252 non-null    int64
#  13  Sejong            252 non-null    int64
#  14  Ulsan             252 non-null    int64
#  15  Jeollanamdo       252 non-null    int64
# ...

# %%
df.describe()
# Out:
#               Year       Month  Temperature     Gangwondo          Seoul  \
# count   252.000000  252.000000   252.000000    252.000000     252.000000
# mean   2010.000000    6.500000    13.367381  21187.654762  381844.194444
# std       6.067351    3.458922     9.540984  13849.668618  229323.680039
# min    2000.000000    1.000000    -5.740000   2800.000000  108894.000000
# 25%    2005.000000    3.750000     4.657500  11510.000000  173070.000000
# 50%    2010.000000    6.500000    14.315000  17421.000000  305387.000000
# 75%    2015.000000    9.250000    22.260000  27480.250000  595902.250000
# max    2020.000000   12.000000    28.560000  64248.000000  928709.000000
#
#           Gyeonggido        Incheon  Gyeongsangnamdo  Gyeongsangbukdo  \
# count     252.000000     252.000000       252.000000       252.000000
# mean   364211.321429  116839.166667     69503.865079     91440.480159
# std    187675.176062   50204.769577     32343.651403     38831.743548
# ...

# %%
df[df['Temperature'] == df['Temperature'].min()]
# Out:
#      Year  Month  Temperature  Gangwondo   Seoul  Gyeonggido  Incheon  \
# 132  2011      1        -5.74      47123  928709      800313   233451
#
#      Gyeongsangnamdo  Gyeongsangbukdo  Gwangju  ...  Daejeon   Busan  Sejong  \
# 132           128711           173107    96670  ...   120524  200683       0
#
#       Ulsan  Jeollanamdo  Jeollabukdo  Jeju  Chungcheongnamdo  \
# 132  262746        60532       105055  1662            158359
#
#      Chungcheongbukdo      Sum
# 132             93067  3541153
#
# [1 rows x 21 columns]

# %%
df[df['Sum'] == df['Sum'].max()]
# Out:
#      Year  Month  Temperature  Gangwondo   Seoul  Gyeonggido  Incheon  \
# 216  2018      1        -2.52      64248  810317      859780   230689
#
#      Gyeongsangnamdo  Gyeongsangbukdo  Gwangju  ...  Daejeon   Busan  Sejong  \
# 216           157687           192264    99162  ...   120022  215573   11610
#
#       Ulsan  Jeollanamdo  Jeollabukdo  Jeju  Chungcheongnamdo  \
# 216  307958        89544       125735  3604            197928
#
#      Chungcheongbukdo      Sum
# 216            113620  3748910
#
# [1 rows x 21 columns]

# %%
df[df['Sum'] == df['Sum'].min()]
# Out:
#    Year  Month  Temperature  Gangwondo   Seoul  Gyeonggido  Incheon  \
# 7  2000      8        26.26       2800  108894       91000    32372
#
#    Gyeongsangnamdo  Gyeongsangbukdo  Gwangju  ...  Daejeon  Busan  Sejong  \
# 7            16218            29922    10695  ...    13005  33843       0
#
#    Ulsan  Jeollanamdo  Jeollabukdo  Jeju  Chungcheongnamdo  Chungcheongbukdo  \
# 7  38071        11105        10051     0             11623              9412
#
#       Sum
# 7  451322
#
# [1 rows x 21 columns]

# %%
df.mean().astype('int64')
# Out:
# Year                   2010
# Month                     6
# Temperature              13
# Gangwondo             21187
# Seoul                381844
# Gyeonggido           364211
# Incheon              116839
# Gyeongsangnamdo       69503
# Gyeongsangbukdo       91440
# Gwangju               42210
# Daegu                 71567
# Daejeon               49795
# Busan                 96483
# Sejong                 2723
# Ulsan                139338
# Jeollanamdo           36998
# Jeollabukdo           52306
# Jeju                    813
# Chungcheongnamdo      84594
# Chungcheongbukdo      44715
# Sum                 1666574
# dtype: int64
